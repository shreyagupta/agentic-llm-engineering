# %% [markdown]
# # Creating an agent that can predict the price based on item description

# %% [markdown]
# ## 1) Deploy Pricing model using Modal
#
# I deploy the pricing model using Modal. The pricing model is in the file `pricer_service2.py`. It is constructed in an optimized way so that the model only needs to be loaded once and can be used for many instances. This will help get quicker predictions for multiple item descriptions at inferece.

# %%
import modal

# %%
# !modal deploy -m pricer_service
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount
#     /Users/shreyagupta/projects/deep-llm-engineering/Agentic_Models_LLM_RAG/pric
# ⠦ Creating objects...
# └── ⠸ Creating mount
#     /Users/shreyagupta/projects/deep-llm-engineering/Agentic_Models_LLM_RAG/pric
# ⠏ Creating objects...
# └── ⠦ Creating mount
#     /Users/shreyagupta/projects/deep-llm-engineering/Agentic_Models_LLM_RAG/pric
# ⠹ Creating objects...
# ├── 🔨 Created mount
# │   /Users/shreyagupta/projects/deep-llm-engineering/Agentic_Models_LLM_RAG/pric
# │   er_service.py
# ⠼ Creating objects...
# ├── 🔨 Created mount
# │   /Users/shreyagupta/projects/deep-llm-engineering/Agentic_Models_LLM_RAG/pric
# │   er_service.py
# └── 🔨 Created function price.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/shreyagupta/projects/deep-llm-engineering/Agentic_Models_LLM_RAG/pric
# │   er_service.py
# └── 🔨 Created function price.
# ✓ App deployed in 1.742s! 🎉
#
# View Deployment:
# ...

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 133.0

# %% [markdown]
# ## 2) An Agent class is created and added.
#
# ### This will be the class where all the agents will be defined.
#
# Here I call the `SpecialistAgent` that I have created to predict price of an item using "pricer_service" that in turn uses the pricing model that I created by finetuning llama-3.1 using 400K training samples!

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# 299.0

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 16 pro max")
# Out:
# 799.0

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 17 pro max")
# Out:
# 799.0

# %% [markdown]
# # Now onto cretaing RAG in Part 2!
